# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from dateutil.parser import parse
from scipy.stats import linregress

# %%
data = pd.read_csv('casos.csv',index_col=0,parse_dates=True)
data.dropna(inplace=True) # cerciorate de no tener NaNs
data
# Out:
#                             Ti       Tcub  Tcub_0p19  Tcub_0p05  Tcub_0p025  \
# tiempo
# 2019-06-08 00:10:00  25.306139  25.036700  23.592609  24.765018   25.091681
# 2019-06-08 00:20:00  25.269413  24.979085  23.574575  24.869893   25.213237
# 2019-06-08 00:30:00  25.209189  24.956076  23.861515  24.988382   25.294594
# 2019-06-08 00:40:00  25.156427  24.909858  23.737467  24.915712   25.238884
# 2019-06-08 00:50:00  25.127161  24.851445  23.516480  24.788149   25.141836
# ...                        ...        ...        ...        ...         ...
# 2019-06-23 23:10:00  26.672542  25.791181  25.427533  26.066076   26.238196
# 2019-06-23 23:20:00  26.612512  25.756900  25.465102  26.066873   26.221364
# 2019-06-23 23:30:00  26.558019  25.707277  25.355715  26.020645   26.176999
# 2019-06-23 23:40:00  26.506948  25.646247  25.113771  25.902241   26.094667
# 2019-06-23 23:50:00  26.427689  25.631489  25.069762  25.869270   26.074189
#
#                      Tcub_0p04  Tcub_0p035  Tcub_0p0375
# tiempo
# 2019-06-08 00:10:00  24.888586   24.954386    24.921532
# 2019-06-08 00:20:00  25.002323   25.070844    25.036599
# 2019-06-08 00:30:00  25.105636   25.166428    25.135840
# 2019-06-08 00:40:00  25.038163   25.102418    25.069956
# 2019-06-08 00:50:00  24.921678   24.992176    24.956559
# ...                        ...         ...          ...
# 2019-06-23 23:10:00  26.129171   26.163448    26.146367
# 2019-06-23 23:20:00  26.135410   26.165139    26.150348
# 2019-06-23 23:30:00  26.090065   26.120280    26.105313
# 2019-06-23 23:40:00  25.980876   26.018797    25.999995
# 2019-06-23 23:50:00  25.952454   25.992850    25.972803
#
# [750 rows x 8 columns]

# %%
# Para el caso 0.01
Ti_s = data.Tcub

fig, ax = plt.subplots(figsize=(6,6))


x = np.linspace(-10,10,2)
y = x 

X = np.array( data.Ti-data.Ti.mean()   )
Y = np.array( Ti_s-data.Ti.mean() )
m,b,r_value, p_value,std_err = linregress(X,Y)

ax.scatter(X,Y)
ax.plot(x,y,'k-') 
ax.plot(x,x*m+b,'r-') 


ax.set_xlim(-10,10)
ax.set_ylim(-10,10)
ax.set_box_aspect(1)
ax.set_ylabel('Ti_s [°C]')
ax.set_xlabel('Ti   [°C]')
ax.grid()
print(m,b,r_value)
# Out:
# 0.6363752509871289 -0.3823672096380228 0.95923779766251

# %%
# Para el caso 0.19
Ti_s = data.Tcub_0p19

fig, ax = plt.subplots(figsize=(6,6))


x = np.linspace(-10,10,2)
y = x 

X = np.array( data.Ti-data.Ti.mean()   )
Y = np.array( Ti_s-data.Ti.mean() )
m,b,r_value, p_value,std_err = linregress(X,Y)

ax.scatter(X,Y)
ax.plot(x,y,'k-') 
ax.plot(x,x*m+b,'r-') 


ax.set_xlim(-10,10)
ax.set_ylim(-10,10)
ax.set_box_aspect(1)
ax.set_ylabel('Ti_s [°C]')
ax.set_xlabel('Ti   [°C]')
ax.grid()
print(m,b,r_value)
# Out:
# 0.991908230209647 -0.6648075450044901 0.9180416464859498

# %%
# Para el caso 0.05
Ti_s = data.Tcub_0p05

fig, ax = plt.subplots(figsize=(6,6))


x = np.linspace(-10,10,2)
y = x 

X = np.array( data.Ti-data.Ti.mean()   )
Y = np.array( Ti_s-data.Ti.mean() )
m,b,r_value, p_value,std_err = linregress(X,Y)

ax.scatter(X,Y)
ax.plot(x,y,'k-') 
ax.plot(x,x*m+b,'r-') 


ax.set_xlim(-10,10)
ax.set_ylim(-10,10)
ax.set_box_aspect(1)
ax.set_ylabel('Ti_s [°C]')
ax.set_xlabel('Ti   [°C]')
ax.grid()
print(m,b,r_value)
# Out:
# 0.7368587451454748 -0.1789985668163508 0.9515518247528577

# %%
# Para el caso 0.04
Ti_s = data.Tcub_0p04

fig, ax = plt.subplots(figsize=(12,12))


x = np.linspace(-10,10,2)
y = x 

X = np.array( data.Ti-data.Ti.mean()   )
Y = np.array( Ti_s-data.Ti.mean() )
m,b,r_value, p_value,std_err = linregress(X,Y)

ax.scatter(X,Y)
ax.plot(x,y,'k-') 
ax.plot(x,x*m+b,'r-') 


ax.set_xlim(-10,10)
ax.set_ylim(-10,10)
ax.set_box_aspect(1)
ax.set_ylabel('Ti_s [°C]')
ax.set_xlabel('Ti   [°C]')
ax.grid()
plt.title('Regresión lineal con Coeficiente de Inflitración = 0.04')
plt.savefig('coef0p04.png')
print(m,b,r_value)
# Out:
# 0.7078406205910379 -0.11756044328237548 0.955103701382273

# %%
# Para el caso 0.035
Ti_s = data.Tcub_0p035

fig, ax = plt.subplots(figsize=(6,6))


x = np.linspace(-10,10,2)
y = x 

X = np.array( data.Ti-data.Ti.mean()   )
Y = np.array( Ti_s-data.Ti.mean() )
m,b,r_value, p_value,std_err = linregress(X,Y)

ax.scatter(X,Y)
ax.plot(x,y,'k-') 
ax.plot(x,x*m+b,'r-') 


ax.set_xlim(-10,10)
ax.set_ylim(-10,10)
ax.set_box_aspect(1)
ax.set_ylabel('Ti_s [°C]')
ax.set_xlabel('Ti   [°C]')
ax.grid()
print(m,b,r_value)
# Out:
# 0.6926014994684083 -0.0847820018597038 0.9564100067567597

# %%
# Para el caso 0.0375
Ti_s = data.Tcub_0p0375

fig, ax = plt.subplots(figsize=(6,6))


x = np.linspace(-10,10,2)
y = x 

X = np.array( data.Ti-data.Ti.mean()   )
Y = np.array( Ti_s-data.Ti.mean() )
m,b,r_value, p_value,std_err = linregress(X,Y)

ax.scatter(X,Y)
ax.plot(x,y,'k-') 
ax.plot(x,x*m+b,'r-') 


ax.set_xlim(-10,10)
ax.set_ylim(-10,10)
ax.set_box_aspect(1)
ax.set_ylabel('Ti_s [°C]')
ax.set_xlabel('Ti   [°C]')
ax.grid()
print(m,b,r_value)
# Out:
# 0.7000217371880105 -0.10060303617058196 0.9559526800457702

# %%
data[['Ti','Tcub','Tcub_0p19','Tcub_0p05','Tcub_0p025','Tcub_0p04','Tcub_0p035','Tcub_0p0375']].corr()
# Out:
#                    Ti      Tcub  Tcub_0p19  Tcub_0p05  Tcub_0p025  Tcub_0p04  \
# Ti           1.000000  0.959238   0.918042   0.951552    0.958524   0.955104
# Tcub         0.959238  1.000000   0.933513   0.983144    0.996083   0.988670
# Tcub_0p19    0.918042  0.933513   1.000000   0.980069    0.955461   0.972848
# Tcub_0p05    0.951552  0.983144   0.980069   1.000000    0.994446   0.999361
# Tcub_0p025   0.958524  0.996083   0.955461   0.994446    1.000000   0.997526
# Tcub_0p04    0.955104  0.988670   0.972848   0.999361    0.997526   1.000000
# Tcub_0p035   0.956410  0.991247   0.968110   0.998399    0.998753   0.999753
# Tcub_0p0375  0.955953  0.990051   0.970549   0.998941    0.998186   0.999943
#
#              Tcub_0p035  Tcub_0p0375
# Ti             0.956410     0.955953
# Tcub           0.991247     0.990051
# Tcub_0p19      0.968110     0.970549
# Tcub_0p05      0.998399     0.998941
# Tcub_0p025     0.998753     0.998186
# Tcub_0p04      0.999753     0.999943
# Tcub_0p035     1.000000     0.999911
# Tcub_0p0375    0.999911     1.000000

# %%
nombres = ['Tcub', 'Tcub_0p19', 'Tcub_0p05','Tcub_0p025','Tcub_0p04','Tcub_0p035','Tcub_0p0375']
for i in nombres:
    print(i,data.Ti.corr(data[i]))
#0.03 --- 0.01
# Out:
# Tcub 0.9592377976625099
# Tcub_0p19 0.9180416464859499
# Tcub_0p05 0.9515518247528577
# Tcub_0p025 0.9585235686480102
# Tcub_0p04 0.9551037013822732
# Tcub_0p035 0.95641000675676
# Tcub_0p0375 0.9559526800457697

# %%
for i in nombres:
    print(i,((data[i] - data.Ti)**2).mean()**.5)
#0.05
# Out:
# Tcub 0.9615196341863687
# Tcub_0p19 1.1382666480133747
# Tcub_0p05 0.7859318212776232
# Tcub_0p025 0.8483516316175913
# Tcub_0p04 0.7968318602782279
# Tcub_0p035 0.8090559219109534
# Tcub_0p0375 0.8021288818406491

# %%
for i in nombres:
    print(i,(data[i]-data.Ti).mean())
#0.025
# Out:
# Tcub -0.38236720963802706
# Tcub_0p19 -0.6648075450044907
# Tcub_0p05 -0.1789985668163539
# Tcub_0p025 -0.011272935141982568
# Tcub_0p04 -0.11756044328237887
# Tcub_0p035 -0.08478200185970744
# Tcub_0p0375 -0.1006030361705856

# %%
for i in nombres:
    print(i,(data[i].resample("1D").max() - data.Ti.resample("1D").max()).mean())
#0.05
# Out:
# Tcub -0.8476961825885034
# Tcub_0p19 0.31740809726885705
# Tcub_0p05 -0.23194167470655222
# Tcub_0p025 -0.3780061006174377
# Tcub_0p04 -0.2839948502184934
# Tcub_0p035 -0.3135832416754205
# Tcub_0p0375 -0.2977350211810048

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-50f848e147b4> in <module>
#       1 for i in nombres:
# ----> 2     df_s = (data[i].resample("1D").max() - data[i].resample("1D").min()) / (data.To_esolmet.resample("1D").max() - data.To_esolmet.resample("1D").min())
#       3     df_e = (data.Ti.resample("1D").max() - data.Ti.resample("1D").min()) / (data.To_esolmet.resample("1D").max() - data.To_esolmet.resample("1D").min())
#       4
#       5     print(i,(df_s - df_e).mean())
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'To_esolmet'
